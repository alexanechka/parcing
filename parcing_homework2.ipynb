# %% [markdown]
# Необходимо собрать информацию о вакансиях на вводимую должность (используем input или через аргументы получаем должность) с сайтов HH(обязательно) и/или Superjob(по желанию). Приложение должно анализировать несколько страниц сайта (также вводим через input или аргументы). Получившийся список должен содержать в себе минимум:
# Наименование вакансии.
# Предлагаемую зарплату (разносим в три поля: минимальная и максимальная и валюта. цифры преобразуем к цифрам).
# Ссылку на саму вакансию.
# Сайт, откуда собрана вакансия.
# По желанию можно добавить ещё параметры вакансии (например, работодателя и расположение). Структура должна быть одинаковая для вакансий с обоих сайтов. Общий результат можно вывести с помощью dataFrame через pandas. Сохраните в json либо csv.

# %%
import requests
import json
import pandas as pd

# %%
url = 'https://api.hh.ru/vacancies'
params = {
    'specialization': '1',
    'area': '1',
    'text': 'Ведущий программист'
}
req = requests.get(url, params)
if req.status_code == 200:
    answer = req.json()
else:
    answer = req.status_code
    
answer
# Out:
# {'items': [{'id': '51794644',
#    'premium': False,
#    'name': 'Ведущий программист',
#    'department': None,
#    'has_test': False,
#    'response_letter_required': False,
#    'area': {'id': '1', 'name': 'Москва', 'url': 'https://api.hh.ru/areas/1'},
#    'salary': None,
#    'type': {'id': 'open', 'name': 'Открытая'},
#    'address': {'city': 'Москва',
#     'street': 'Электрозаводская улица',
#     'building': '21',
#     'description': None,
#     'lat': 55.786505,
#     'lng': 37.704134,
#     'raw': 'Москва, Электрозаводская улица, 21',
#     'metro': {'station_name': 'Электрозаводская',
#      'line_name': 'Арбатско-Покровская',
#      'station_id': '3.161',
#      'line_id': '3',
#      'lat': 55.782057,
#      'lng': 37.7053},
#     'metro_stations': [{'station_name': 'Электрозаводская',
#       'line_name': 'Арбатско-Покровская',
#       'station_id': '3.161',
#       'line_id': '3',
#       'lat': 55.782057,
#       'lng': 37.7053}],
#     'id': '527575'},
#    'response_url': None,
#    'sort_point_distance': None,
#    'published_at': '2022-05-08T15:45:08+0300',
#    'created_at': '2022-05-08T15:45:08+0300',
#    'archived': False,
#    'apply_alternate_url': 'https://hh.ru/applicant/vacancy_response?vacancyId=51794644',
#    'insider_interview': None,
#    'url': 'https://api.hh.ru/vacancies/51794644?host=hh.ru',
#    'alternate_url': 'https://hh.ru/vacancy/51794644',
#    'relations': [],
#    'employer': {'id': '180856',
#     'name': 'АВП-Технология',
#     'url': 'https://api.hh.ru/employers/180856',
#     'alternate_url': 'https://hh.ru/employer/180856',
#     'logo_urls': {'240': 'https://hhcdn.ru/employer-logo/705678.png',
#      'original': 'https://hhcdn.ru/employer-logo-original/195555.png',
#      '90': 'https://hhcdn.ru/employer-logo/705677.png'},
#     'vacancies_url': 'https://api.hh.ru/vacancies?employer_id=180856',
#     'trusted': True},
#    'snippet': {'requirement': 'Уверенное владение С и STL. Понимание принципов ООП. Опыт разработки и отладки многопоточных приложений. Умение писать поддерживаемый код (читаемый, расширяемый...). ',
#     'responsibility': 'Разработка новой функциональности ПО систем автоматизированного ведения поездов. Разработка программных модулей для управления новыми типами подвижного состава.'},
#    'contacts': None,
#    'schedule': {'id': 'fullDay', 'name': 'Полный день'},
#    'working_days': [],
#    'working_time_intervals': [],
#    'working_time_modes': [],
#    'accept_temporary': False},
#   {'id': '54892884',
#    'premium': False,
#    'name': 'Ведущий программист',
#    'department': None,
#    'has_test': False,
#    'response_letter_required': False,
#    'area': {'id': '1', 'name': 'Москва', 'url': 'https://api.hh.ru/areas/1'},
#    'salary': None,
#    'type': {'id': 'open', 'name': 'Открытая'},
#    'address': {'city': 'Москва',
#     'street': 'Волгоградский проспект',
#     'building': '42к5',
#     'description': None,
#     'lat': 55.709282,
#     'lng': 37.721687,
#     'raw': 'Москва, Волгоградский проспект, 42к5',
#     'metro': {'station_name': 'Текстильщики',
#      'line_name': 'Таганско-Краснопресненская',
#      'station_id': '7.139',
#      'line_id': '7',
#      'lat': 55.709211,
#      'lng': 37.732117},
#     'metro_stations': [{'station_name': 'Текстильщики',
#       'line_name': 'Таганско-Краснопресненская',
#       'station_id': '7.139',
#       'line_id': '7',
#       'lat': 55.709211,
#       'lng': 37.732117}],
#     'id': '586340'},
#    'response_url': None,
#    'sort_point_distance': None,
#    'published_at': '2022-05-09T14:52:19+0300',
#    'created_at': '2022-05-09T14:52:19+0300',
#    'archived': False,
#    'apply_alternate_url': 'https://hh.ru/applicant/vacancy_response?vacancyId=54892884',
#    'insider_interview': None,
#    'url': 'https://api.hh.ru/vacancies/54892884?host=hh.ru',
#    'alternate_url': 'https://hh.ru/vacancy/54892884',
#    'relations': [],
#    'employer': {'id': '11261',
#     'name': 'Концерн Гудвин (Гудвин Европа)',
#     'url': 'https://api.hh.ru/employers/11261',
#     'alternate_url': 'https://hh.ru/employer/11261',
#     'logo_urls': {'original': 'https://hhcdn.ru/employer-logo-original/229633.png',
#      '240': 'https://hhcdn.ru/employer-logo/680292.png',
#      '90': 'https://hhcdn.ru/employer-logo/680291.png'},
#     'vacancies_url': 'https://api.hh.ru/vacancies?employer_id=11261',
#     'trusted': True},
#    'snippet': {'requirement': 'Написание WEB API сервисов, использование и конфигурирование REST API 1C, API Яндекс.Карт. Знание JavaScript. Операционная система Linux. ',
#     'responsibility': 'Разработка программного обеспечения.'},
#    'contacts': None,
#    'schedule': {'id': 'fullDay', 'name': 'Полный день'},
#    'working_days': [],
#    'working_time_intervals': [],
#    'working_time_modes': [],
#    'accept_temporary': False},
#   {'id': '54718245',
#    'premium': False,
#    'name': 'C# .Net MVC Developer',
#    'department': None,
#    'has_test': False,
#    'response_letter_required': False,
#    'area': {'id': '1', 'name': 'Москва', 'url': 'https://api.hh.ru/areas/1'},
#    'salary': {'from': 6000, 'to': 7500, 'currency': 'USD', 'gross': True},
#    'type': {'id': 'open', 'name': 'Открытая'},
#    'address': None,
#    'response_url': None,
#    'sort_point_distance': None,
#    'published_at': '2022-05-08T10:54:21+0300',
#    'created_at': '2022-05-08T10:54:21+0300',
#    'archived': False,
#    'apply_alternate_url': 'https://hh.ru/applicant/vacancy_response?vacancyId=54718245',
#    'insider_interview': None,
#    'url': 'https://api.hh.ru/vacancies/54718245?host=hh.ru',
#    'alternate_url': 'https://hh.ru/vacancy/54718245',
#    'relations': [],
#    'employer': {'id': '4955407',
#     'name': 'Top Remote Talent',
#     'url': 'https://api.hh.ru/employers/4955407',
#     'alternate_url': 'https://hh.ru/employer/4955407',
#     'logo_urls': {'240': 'https://hhcdn.ru/employer-logo/3954496.png',
#      '90': 'https://hhcdn.ru/employer-logo/3954495.png',
#      'original': 'https://hhcdn.ru/employer-logo-original/878405.png'},
#     'vacancies_url': 'https://api.hh.ru/vacancies?employer_id=4955407',
#     'trusted': True},
#    'snippet': {'requirement': 'A <highlighttext>leading</highlighttext> UCaaS solutions company with offices in India, UAE and over 15 years’ experience serving enterprises is seeking a...',
#     'responsibility': None},
#    'contacts': None,
#    'schedule': {'id': 'remote', 'name': 'Удаленная работа'},
#    'working_days': [],
#    'working_time_intervals': [],
#    'working_time_modes': [],
#    'accept_temporary': True},
#   {'id': '55254339',
#    'premium': False,
#    'name': 'Full stack C# Developer (C# JS), Кипр',
#    'department': None,
#    'has_test': False,
#    'response_letter_required': False,
#    'area': {'id': '1', 'name': 'Москва', 'url': 'https://api.hh.ru/areas/1'},
#    'salary': {'from': 7000, 'to': None, 'currency': 'EUR', 'gross': True},
#    'type': {'id': 'open', 'name': 'Открытая'},
#    'address': {'city': 'Лимассол',
#     'street': None,
#     'building': None,
#     'description': None,
#     'lat': 34.687526,
#     'lng': 33.042165,
#     'raw': 'Лимассол',
#     'metro': None,
#     'metro_stations': [],
#     'id': '1143417'},
#    'response_url': None,
#    'sort_point_distance': None,
#    'published_at': '2022-05-06T14:23:27+0300',
#    'created_at': '2022-05-06T14:23:27+0300',
#    'archived': False,
#    'apply_alternate_url': 'https://hh.ru/applicant/vacancy_response?vacancyId=55254339',
#    'insider_interview': None,
#    'url': 'https://api.hh.ru/vacancies/55254339?host=hh.ru',
#    'alternate_url': 'https://hh.ru/vacancy/55254339',
#    'relations': [],
#    'employer': {'id': '988940',
#     'name': 'MetaQuotes Software Corp.',
#     'url': 'https://api.hh.ru/employers/988940',
#     'alternate_url': 'https://hh.ru/employer/988940',
#     'logo_urls': {'240': 'https://hhcdn.ru/employer-logo/663792.png',
#      '90': 'https://hhcdn.ru/employer-logo/663791.png',
#      'original': 'https://hhcdn.ru/employer-logo-original/99361.gif'},
#     'vacancies_url': 'https://api.hh.ru/vacancies?employer_id=988940',
#     'trusted': True},
#    'snippet': {'requirement': 'Навыки разработки серверных и клиентских решений с использованием ASP.NET, C#, JavaScript, CSS и HTML. Знание и опыт настройки Microsoft IIS. ',
#     'responsibility': 'Первичный отбор по резюме. Тестовое задание (срок выполнения - без строгих ограничений). Техническое интервью по Skype с видео по итогам решения...'},
#    'contacts': None,
#    'schedule': {'id': 'fullDay', 'name': 'Полный день'},
#    'working_days': [],
#    'working_time_intervals': [],
#    'working_time_modes': [],
#    'accept_temporary': False},
#   {'id': '55243692',
#    'premium': False,
#    'name': 'Ведущий программист/Разработчик 1С',
#    'department': None,
#    'has_test': False,
#    'response_letter_required': False,
#    'area': {'id': '1', 'name': 'Москва', 'url': 'https://api.hh.ru/areas/1'},
#    'salary': {'from': 250000, 'to': None, 'currency': 'RUR', 'gross': True},
#    'type': {'id': 'open', 'name': 'Открытая'},
#    'address': {'city': 'Москва',
#     'street': 'Нижний Сусальный переулок',
#     'building': '5с15',
#     'description': None,
#     'lat': 55.758509,
#     'lng': 37.664384,
#     'raw': 'Москва, Нижний Сусальный переулок, 5с15',
#     'metro': {'station_name': 'Курская',
#      'line_name': 'Кольцевая',
#      'station_id': '5.71',
#      'line_id': '5',
#      'lat': 55.758631,
#      'lng': 37.661059},
#     'metro_stations': [{'station_name': 'Курская',
#       'line_name': 'Кольцевая',
#       'station_id': '5.71',
#       'line_id': '5',
#       'lat': 55.758631,
#       'lng': 37.661059}],
#     'id': '111101'},
#    'response_url': None,
#    'sort_point_distance': None,
#    'published_at': '2022-05-06T10:33:46+0300',
#    'created_at': '2022-05-06T10:33:46+0300',
#    'archived': False,
#    'apply_alternate_url': 'https://hh.ru/applicant/vacancy_response?vacancyId=55243692',
#    'insider_interview': None,
#    'url': 'https://api.hh.ru/vacancies/55243692?host=hh.ru',
#    'alternate_url': 'https://hh.ru/vacancy/55243692',
#    'relations': [],
#    'employer': {'id': '891969',
#     'name': 'Тоталлук',
#     'url': 'https://api.hh.ru/employers/891969',
#     'alternate_url': 'https://hh.ru/employer/891969',
#     'logo_urls': {'original': 'https://hhcdn.ru/employer-logo-original/899931.jpg',
#      '90': 'https://hhcdn.ru/employer-logo/4040411.jpeg',
#      '240': 'https://hhcdn.ru/employer-logo/4040412.jpeg'},
#     'vacancies_url': 'https://api.hh.ru/vacancies?employer_id=891969',
#     'trusted': True},
#    'snippet': {'requirement': 'Знание (опыт работы) конфигураций: Желательно: ЗУП 3. Розница 2. - Обязательно наличие опыта в проектировании и разработке новых блоков (для автоматизации...',
#     'responsibility': 'Сопровождение и доработка системы 1С Комплексная автоматизация 1.1/УТ 11. - Проектирование и реализация нового функционала в 1С. - '},
#    'contacts': None,
#    'schedule': {'id': 'fullDay', 'name': 'Полный день'},
#    'working_days': [],
#    'working_time_intervals': [],
#    'working_time_modes': [],
#    'accept_temporary': False},
#   {'id': '55269828',
#    'premium': False,
#    'name': 'С/С++ Linux разработчик (remote)',
#    'department': None,
#    'has_test': False,
#    'response_letter_required': False,
#    'area': {'id': '1', 'name': 'Москва', 'url': 'https://api.hh.ru/areas/1'},
#    'salary': {'from': None, 'to': 6000, 'currency': 'USD', 'gross': True},
#    'type': {'id': 'open', 'name': 'Открытая'},
#    'address': {'city': 'Сиэтл',
#     'street': '4th Ave',
#     'building': None,
#     'description': None,
#     'lat': 47.595738,
#     'lng': -122.329027,
#     'raw': 'Сиэтл, 4th Ave',
#     'metro': None,
#     'metro_stations': [],
#     'id': '1296201'},
#    'response_url': None,
#    'sort_point_distance': None,
#    'published_at': '2022-05-09T16:51:27+0300',
#    'created_at': '2022-05-09T16:51:27+0300',
#    'archived': False,
#    'apply_alternate_url': 'https://hh.ru/applicant/vacancy_response?vacancyId=55269828',
#    'insider_interview': None,
#    'url': 'https://api.hh.ru/vacancies/55269828?host=hh.ru',
#    'alternate_url': 'https://hh.ru/vacancy/55269828',
#    'relations': [],
#    'employer': {'id': '3366396',
#     'name': 'Темпеста',
#     'url': 'https://api.hh.ru/employers/3366396',
#     'alternate_url': 'https://hh.ru/employer/3366396',
#     'logo_urls': {'original': 'https://hhcdn.ru/employer-logo-original/520526.png',
#      '240': 'https://hhcdn.ru/employer-logo/2523582.png',
#      '90': 'https://hhcdn.ru/employer-logo/2523581.png'},
#     'vacancies_url': 'https://api.hh.ru/vacancies?employer_id=3366396',
#     'trusted': True},
#    'snippet': {'requirement': 'Обязательные навыки: Уверенное владение C, хороший С или желание его изучить. Хорошее понимание устройства Linux и его системного API. ',
#     'responsibility': None},
#    'contacts': None,
#    'schedule': {'id': 'remote', 'name': 'Удаленная работа'},
#    'working_days': [],
#    'working_time_intervals': [],
#    'working_time_modes': [],
#    'accept_temporary': False},
#   {'id': '54981052',
#    'premium': False,
#    'name': 'Ведущий программист С++',
#    'department': None,
#    'has_test': False,
#    'response_letter_required': False,
#    'area': {'id': '1', 'name': 'Москва', 'url': 'https://api.hh.ru/areas/1'},
#    'salary': {'from': 150000, 'to': 350000, 'currency': 'RUR', 'gross': False},
#    'type': {'id': 'open', 'name': 'Открытая'},
#    'address': {'city': None,
#     'street': None,
#     'building': None,
#     'description': None,
#     'lat': None,
#     'lng': None,
#     'raw': None,
#     'metro': {'station_name': 'Менделеевская',
#      'line_name': 'Серпуховско-Тимирязевская',
#      'station_id': '9.83',
#      'line_id': '9',
#      'lat': 55.781999,
#      'lng': 37.599141},
#     'metro_stations': [{'station_name': 'Менделеевская',
#       'line_name': 'Серпуховско-Тимирязевская',
#       'station_id': '9.83',
#       'line_id': '9',
#       'lat': 55.781999,
#       'lng': 37.599141},
#      {'station_name': 'Новослободская',
#       'line_name': 'Кольцевая',
#       'station_id': '5.82',
#       'line_id': '5',
#       'lat': 55.779606,
#       'lng': 37.601252},
#      {'station_name': 'Савёловская',
#       'line_name': 'Серпуховско-Тимирязевская',
#       'station_id': '9.128',
#       'line_id': '9',
#       'lat': 55.794054,
#       'lng': 37.587163},
#      {'station_name': 'Савёловская',
#       'line_name': 'МЦД - 1',
#       'station_id': '131.699',
#       'line_id': '131',
#       'lat': 55.793936,
#       'lng': 37.587038}],
#     'id': '7458335'},
#    'response_url': None,
#    'sort_point_distance': None,
#    'published_at': '2022-05-09T14:41:41+0300',
#    'created_at': '2022-05-09T14:41:41+0300',
#    'archived': False,
#    'apply_alternate_url': 'https://hh.ru/applicant/vacancy_response?vacancyId=54981052',
#    'insider_interview': None,
#    'url': 'https://api.hh.ru/vacancies/54981052?host=hh.ru',
#    'alternate_url': 'https://hh.ru/vacancy/54981052',
#    'relations': [],
#    'employer': {'id': '4729',
#     'name': 'Эверис, Представительство',
#     'url': 'https://api.hh.ru/employers/4729',
#     'alternate_url': 'https://hh.ru/employer/4729',
#     'logo_urls': {'original': 'https://hhcdn.ru/employer-logo-original/573710.png',
#      '90': 'https://hhcdn.ru/employer-logo/2736210.png',
#      '240': 'https://hhcdn.ru/employer-logo/2736211.png'},
#     'vacancies_url': 'https://api.hh.ru/vacancies?employer_id=4729',
#     'trusted': True},
#    'snippet': {'requirement': 'Навыки объектно-ориентированного проектирования, умение и желание писать качественный код. Желателен опыт работы с junior-<highlighttext>программистами</highlighttext> или в команде, распределения...',
#     'responsibility': 'Написание и отладка кода, в основном для <highlighttext>головного</highlighttext> продукта. Ведение проектов в небольшой команде, приемка кода, сделанного другими (code review).'},
#    'contacts': None,
#    'schedule': {'id': 'flexible', 'name': 'Гибкий график'},
#    'working_days': [],
#    'working_time_intervals': [],
#    'working_time_modes': [],
#    'accept_temporary': False},
#   {'id': '55001846',
#    'premium': False,
#    'name': 'Ведущий программист 1С',
#    'department': None,
#    'has_test': False,
#    'response_letter_required': False,
#    'area': {'id': '1', 'name': 'Москва', 'url': 'https://api.hh.ru/areas/1'},
#    'salary': {'from': 150000, 'to': 300000, 'currency': 'RUR', 'gross': False},
#    'type': {'id': 'open', 'name': 'Открытая'},
#    'address': {'city': 'Москва',
#     'street': 'Последний переулок',
#     'building': '24',
#     'description': None,
#     'lat': 55.769788,
#     'lng': 37.629565,
#     'raw': 'Москва, Последний переулок, 24',
#     'metro': None,
#     'metro_stations': [],
#     'id': '5867751'},
#    'response_url': None,
#    'sort_point_distance': None,
#    'published_at': '2022-05-07T12:40:33+0300',
#    'created_at': '2022-05-07T12:40:33+0300',
#    'archived': False,
#    'apply_alternate_url': 'https://hh.ru/applicant/vacancy_response?vacancyId=55001846',
#    'insider_interview': None,
#    'url': 'https://api.hh.ru/vacancies/55001846?host=hh.ru',
#    'alternate_url': 'https://hh.ru/vacancy/55001846',
#    'relations': [],
#    'employer': {'id': '3919953',
#     'name': 'Барс',
#     'url': 'https://api.hh.ru/employers/3919953',
#     'alternate_url': 'https://hh.ru/employer/3919953',
#     'logo_urls': {'original': 'https://hhcdn.ru/employer-logo-original/877778.png',
#      '240': 'https://hhcdn.ru/employer-logo/3951988.png',
#      '90': 'https://hhcdn.ru/employer-logo/3951987.png'},
#     'vacancies_url': 'https://api.hh.ru/vacancies?employer_id=3919953',
#     'trusted': True},
#    'snippet': {'requirement': 'Опыт работы от 3-х лет. Высшее профессиональное образование. Понимание клиент-серверной архитектуры. Опыт работы с технической документацией и её...',
#     'responsibility': 'Демонтаж зданий и сооружений. Ликвидация техногенных свалок. Рекультивация почв. Переработка отходов I-V класса опасности. Подготовить техническое задание и выбрать...'},
#    'contacts': None,
#    'schedule': {'id': 'remote', 'name': 'Удаленная работа'},
#    'working_days': [],
#    'working_time_intervals': [],
#    'working_time_modes': [],
#    'accept_temporary': False},
#   {'id': '55262147',
#    'premium': False,
#    'name': 'Ведущий программист 1C',
#    'department': None,
#    'has_test': False,
#    'response_letter_required': False,
#    'area': {'id': '1', 'name': 'Москва', 'url': 'https://api.hh.ru/areas/1'},
#    'salary': {'from': None, 'to': 250000, 'currency': 'RUR', 'gross': True},
#    'type': {'id': 'open', 'name': 'Открытая'},
#    'address': None,
#    'response_url': None,
#    'sort_point_distance': None,
#    'published_at': '2022-05-06T19:17:43+0300',
#    'created_at': '2022-05-06T19:17:43+0300',
#    'archived': False,
#    'apply_alternate_url': 'https://hh.ru/applicant/vacancy_response?vacancyId=55262147',
#    'insider_interview': None,
#    'url': 'https://api.hh.ru/vacancies/55262147?host=hh.ru',
#    'alternate_url': 'https://hh.ru/vacancy/55262147',
#    'relations': [],
#    'employer': {'id': '5174849',
#     'name': 'Wanted',
#     'url': 'https://api.hh.ru/employers/5174849',
#     'alternate_url': 'https://hh.ru/employer/5174849',
#     'logo_urls': {'original': 'https://hhcdn.ru/employer-logo-original/927964.jpg',
#      '240': 'https://hhcdn.ru/employer-logo/4152417.jpeg',
#      '90': 'https://hhcdn.ru/employer-logo/4152416.jpeg'},
#     'vacancies_url': 'https://api.hh.ru/vacancies?employer_id=5174849',
#     'trusted': True},
#    'snippet': {'requirement': 'Опыт от 4,5 лет. Опыт работы с ERP, комплексной автоматизацией. Опыт разработки web и http-сервисов.',
#     'responsibility': 'Участие в разработке B2B платформы на базе 1С. Написание инструкций пользователям. Поддержка пользователей в сложных ситуациях, когда...'},
#    'contacts': None,
#    'schedule': {'id': 'flexible', 'name': 'Гибкий график'},
#    'working_days': [],
#    'working_time_intervals': [],
#    'working_time_modes': [],
#    'accept_temporary': False},
#   {'id': '54497894',
#    'premium': False,
#    'name': 'Разработчик Rust',
#    'department': None,
#    'has_test': False,
#    'response_letter_required': False,
#    'area': {'id': '1', 'name': 'Москва', 'url': 'https://api.hh.ru/areas/1'},
#    'salary': {'from': None, 'to': 300000, 'currency': 'RUR', 'gross': False},
#    'type': {'id': 'open', 'name': 'Открытая'},
#    'address': None,
#    'response_url': None,
#    'sort_point_distance': None,
#    'published_at': '2022-05-09T14:12:28+0300',
#    'created_at': '2022-05-09T14:12:28+0300',
#    'archived': False,
#    'apply_alternate_url': 'https://hh.ru/applicant/vacancy_response?vacancyId=54497894',
#    'insider_interview': None,
#    'url': 'https://api.hh.ru/vacancies/54497894?host=hh.ru',
#    'alternate_url': 'https://hh.ru/vacancy/54497894',
#    'relations': [],
#    'employer': {'id': '1951292',
#     'name': 'Современные Бизнес-Аналитические Решения',
#     'url': 'https://api.hh.ru/employers/1951292',
#     'alternate_url': 'https://hh.ru/employer/1951292',
#     'logo_urls': {'90': 'https://hhcdn.ru/employer-logo/4260400.jpeg',
#      '240': 'https://hhcdn.ru/employer-logo/4260401.jpeg',
#      'original': 'https://hhcdn.ru/employer-logo-original/954968.jpg'},
#     'vacancies_url': 'https://api.hh.ru/vacancies?employer_id=1951292',
#     'trusted': True},
#    'snippet': {'requirement': 'Опыт использования и понимание языка Rust. Опыт работы с языками C, C. Опыт оптимизации программ и умение использовать профилировщик. ',
#     'responsibility': 'Проектирование, разработка, тестирование и поддержка ядра ETL сервера. Разработка высокопроизводительных низкоуровневых элементов ПО. Разработка модулей к существующим проектам.'},
#    'contacts': None,
#    'schedule': {'id': 'remote', 'name': 'Удаленная работа'},
#    'working_days': [],
#    'working_time_intervals': [],
#    'working_time_modes': [],
#    'accept_temporary': False},
#   {'id': '55134106',
#    'premium': False,
#    'name': 'Ведущий программист PHP',
#    'department': None,
#    'has_test': False,
#    'response_letter_required': False,
#    'area': {'id': '1', 'name': 'Москва', 'url': 'https://api.hh.ru/areas/1'},
#    'salary': {'from': None, 'to': 300000, 'currency': 'RUR', 'gross': False},
#    'type': {'id': 'open', 'name': 'Открытая'},
#    'address': {'city': 'Москва',
#     'street': '2-я Мелитопольская улица',
#     'building': '4Ас40',
#     'description': None,
#     'lat': 55.534474,
#     'lng': 37.574229,
#     'raw': 'Москва, 2-я Мелитопольская улица, 4Ас40',
#     'metro': None,
#     'metro_stations': [],
#     'id': '792460'},
#    'response_url': None,
#    'sort_point_distance': None,
#    'published_at': '2022-05-07T18:26:26+0300',
#    'created_at': '2022-05-07T18:26:26+0300',
#    'archived': False,
#    'apply_alternate_url': 'https://hh.ru/applicant/vacancy_response?vacancyId=55134106',
#    'insider_interview': None,
#    'url': 'https://api.hh.ru/vacancies/55134106?host=hh.ru',
#    'alternate_url': 'https://hh.ru/vacancy/55134106',
#    'relations': [],
#    'employer': {'id': '38314',
#     'name': 'БЕРГ Холдинг',
#     'url': 'https://api.hh.ru/employers/38314',
#     'alternate_url': 'https://hh.ru/employer/38314',
#     'logo_urls': {'original': 'https://hhcdn.ru/employer-logo-original/224059.jpg',
#      '90': 'https://hhcdn.ru/employer-logo/896453.jpeg',
#      '240': 'https://hhcdn.ru/employer-logo/896454.jpeg'},
#     'vacancies_url': 'https://api.hh.ru/vacancies?employer_id=38314',
#     'trusted': True},
#    'snippet': {'requirement': 'PHP 7.1, MySQL – высокий уровень проектирования и написания кода. Система контроля версий – Git. Умение писать свои API и использовать...',
#     'responsibility': 'Решение технических и бизнес задач. Разработка стабильного читабельного кода. Проверка кода других <highlighttext>разработчиков</highlighttext>. Участие в принятии решений по архитектуре проектов. '},
#    'contacts': None,
#    'schedule': {'id': 'fullDay', 'name': 'Полный день'},
#    'working_days': [],
#    'working_time_intervals': [],
#    'working_time_modes': [],
#    'accept_temporary': False},
#   {'id': '54926043',
#    'premium': False,
#    'name': 'Ведущий программист 1С / архитектор 1С',
#    'department': None,
#    'has_test': False,
#    'response_letter_required': False,
#    'area': {'id': '1', 'name': 'Москва', 'url': 'https://api.hh.ru/areas/1'},
#    'salary': {'from': 108000, 'to': 395000, 'currency': 'RUR', 'gross': True},
#    'type': {'id': 'open', 'name': 'Открытая'},
#    'address': None,
#    'response_url': None,
#    'sort_point_distance': None,
#    'published_at': '2022-05-07T15:23:07+0300',
#    'created_at': '2022-05-07T15:23:07+0300',
#    'archived': False,
#    'apply_alternate_url': 'https://hh.ru/applicant/vacancy_response?vacancyId=54926043',
#    'insider_interview': None,
#    'url': 'https://api.hh.ru/vacancies/54926043?host=hh.ru',
#    'alternate_url': 'https://hh.ru/vacancy/54926043',
#    'relations': [],
#    'employer': {'id': '839098',
#     'name': 'Автомакон',
#     'url': 'https://api.hh.ru/employers/839098',
#     'alternate_url': 'https://hh.ru/employer/839098',
#     'logo_urls': {'240': 'https://hhcdn.ru/employer-logo/4221269.png',
#      '90': 'https://hhcdn.ru/employer-logo/4221268.png',
#      'original': 'https://hhcdn.ru/employer-logo-original/945183.png'},
#     'vacancies_url': 'https://api.hh.ru/vacancies?employer_id=839098',
#     'trusted': True},
#    'snippet': {'requirement': 'Знаете платформу 1С на уровне эксперта. Имеете опыт работы архитектором/<highlighttext>ведущим</highlighttext> <highlighttext>программистом</highlighttext> 1С от 2-х лет. ',
#     'responsibility': 'Обеспечение производительности работ подсистем благодаря архитектурным изменениям и качеству разработки. Проектирование учетных систем. Регламентирование процесса разработки. Архитектурный надзор за системами...'},
#    'contacts': None,
#    'schedule': {'id': 'remote', 'name': 'Удаленная работа'},
#    'working_days': [],
#    'working_time_intervals': [],
#    'working_time_modes': [],
#    'accept_temporary': False},
#   {'id': '47901543',
#    'premium': False,
#    'name': 'Middle BackEnd Developer .Net C# (удаленно)',
#    'department': None,
#    'has_test': False,
#    'response_letter_required': False,
#    'area': {'id': '1', 'name': 'Москва', 'url': 'https://api.hh.ru/areas/1'},
#    'salary': {'from': 200000, 'to': 240000, 'currency': 'RUR', 'gross': False},
#    'type': {'id': 'open', 'name': 'Открытая'},
#    'address': None,
#    'response_url': None,
#    'sort_point_distance': None,
#    'published_at': '2022-05-08T14:45:04+0300',
#    'created_at': '2022-05-08T14:45:04+0300',
#    'archived': False,
#    'apply_alternate_url': 'https://hh.ru/applicant/vacancy_response?vacancyId=47901543',
#    'insider_interview': None,
#    'url': 'https://api.hh.ru/vacancies/47901543?host=hh.ru',
#    'alternate_url': 'https://hh.ru/vacancy/47901543',
#    'relations': [],
#    'employer': {'id': '723714',
#     'name': 'ZennoLab',
#     'url': 'https://api.hh.ru/employers/723714',
#     'alternate_url': 'https://hh.ru/employer/723714',
#     'logo_urls': {'90': 'https://hhcdn.ru/employer-logo/2750763.png',
#      '240': 'https://hhcdn.ru/employer-logo/2750764.png',
#      'original': 'https://hhcdn.ru/employer-logo-original/577373.png'},
#     'vacancies_url': 'https://api.hh.ru/vacancies?employer_id=723714',
#     'trusted': True},
#    'snippet': {'requirement': 'Опыт работы с C# от 3 лет. Опыт разработки на ASP.NET Core от 1 года. Опыт работы с SQL или...',
#     'responsibility': 'Участвовать в разработке новых проектов. Развивать и поддерживать имеющиеся продукты компании (высоконагруженные внешние и внутренние сервисы). Минимальные нагрузки на наши...'},
#    'contacts': None,
#    'schedule': {'id': 'remote', 'name': 'Удаленная работа'},
#    'working_days': [],
#    'working_time_intervals': [],
#    'working_time_modes': [],
#    'accept_temporary': False},
#   {'id': '48775503',
#    'premium': False,
#    'name': 'Разработчик интерпретатора',
#    'department': None,
#    'has_test': False,
#    'response_letter_required': False,
#    'area': {'id': '1', 'name': 'Москва', 'url': 'https://api.hh.ru/areas/1'},
#    'salary': {'from': 300000, 'to': None, 'currency': 'RUR', 'gross': False},
#    'type': {'id': 'open', 'name': 'Открытая'},
#    'address': None,
#    'response_url': None,
#    'sort_point_distance': None,
#    'published_at': '2022-05-07T23:44:58+0300',
#    'created_at': '2022-05-07T23:44:58+0300',
#    'archived': False,
#    'apply_alternate_url': 'https://hh.ru/applicant/vacancy_response?vacancyId=48775503',
#    'insider_interview': None,
#    'url': 'https://api.hh.ru/vacancies/48775503?host=hh.ru',
#    'alternate_url': 'https://hh.ru/vacancy/48775503',
#    'relations': [],
#    'employer': {'id': '5076748',
#     'name': 'Mobigility Inc.',
#     'url': 'https://api.hh.ru/employers/5076748',
#     'alternate_url': 'https://hh.ru/employer/5076748',
#     'logo_urls': {'original': 'https://hhcdn.ru/employer-logo-original/799654.png',
#      '90': 'https://hhcdn.ru/employer-logo/3639503.png',
#      '240': 'https://hhcdn.ru/employer-logo/3639504.png'},
#     'vacancies_url': 'https://api.hh.ru/vacancies?employer_id=5076748',
#     'trusted': True},
#    'snippet': {'requirement': 'Развивать интерпретатор для кастомного скриптового языка программирования, оптимизировать его производительность. Опыт разработки и оптимизации какого-либо интерпретатора. Понимание принципов работы...',
#     'responsibility': 'Договор заключается с юридическим лицом в РФ, расчет производится в рублях.'},
#    'contacts': None,
#    'schedule': {'id': 'remote', 'name': 'Удаленная работа'},
#    'working_days': [],
#    'working_time_intervals': [],
#    'working_time_modes': [],
#    'accept_temporary': True},
#   {'id': '54814745',
#    'premium': False,
#    'name': 'Ведущий программист 1С',
#    'department': None,
#    'has_test': False,
#    'response_letter_required': False,
#    'area': {'id': '1', 'name': 'Москва', 'url': 'https://api.hh.ru/areas/1'},
#    'salary': {'from': 200000, 'to': 250000, 'currency': 'RUR', 'gross': False},
#    'type': {'id': 'open', 'name': 'Открытая'},
#    'address': {'city': 'Москва',
#     'street': 'Калужско-Рижская линия',
#     'building': 'метро Сухаревская',
#     'description': None,
#     'lat': 55.772492,
#     'lng': 37.632305,
#     'raw': 'Москва, Калужско-Рижская линия, метро Сухаревская',
#     'metro': {'station_name': 'Сухаревская',
#      'line_name': 'Калужско-Рижская',
#      'station_id': '6.137',
#      'line_id': '6',
#      'lat': 55.772315,
#      'lng': 37.63285},
#     'metro_stations': [{'station_name': 'Сухаревская',
#       'line_name': 'Калужско-Рижская',
#       'station_id': '6.137',
#       'line_id': '6',
#       'lat': 55.772315,
#       'lng': 37.63285}],
#     'id': '2882501'},
#    'response_url': None,
#    'sort_point_distance': None,
#    'published_at': '2022-05-08T13:23:28+0300',
#    'created_at': '2022-05-08T13:23:28+0300',
#    'archived': False,
#    'apply_alternate_url': 'https://hh.ru/applicant/vacancy_response?vacancyId=54814745',
#    'insider_interview': None,
#    'url': 'https://api.hh.ru/vacancies/54814745?host=hh.ru',
#    'alternate_url': 'https://hh.ru/vacancy/54814745',
#    'relations': [],
#    'employer': {'id': '4173839',
#     'name': 'СтанкоРемСервис',
#     'url': 'https://api.hh.ru/employers/4173839',
#     'alternate_url': 'https://hh.ru/employer/4173839',
#     'logo_urls': {'original': 'https://hhcdn.ru/employer-logo-original/663817.jpg',
#      '240': 'https://hhcdn.ru/employer-logo/3096401.jpeg',
#      '90': 'https://hhcdn.ru/employer-logo/3096400.jpeg'},
#     'vacancies_url': 'https://api.hh.ru/vacancies?employer_id=4173839',
#     'trusted': True},
#    'snippet': {'requirement': 'Опыт программирования 1С: Предприятие от 2-х лет. Хорошие знания СКД, конвертации данных. Опыт работы с 1С ЗУП...',
#     'responsibility': 'Обеспечение необходимой поддержки пользователей на различных конфигурациях продуктов 1С для работы бизнес-процессов. Создание, модификация существующих документов, печатных форм...'},
#    'contacts': None,
#    'schedule': {'id': 'fullDay', 'name': 'Полный день'},
#    'working_days': [],
#    'working_time_intervals': [],
#    'working_time_modes': [],
#    'accept_temporary': False},
#   {'id': '54081874',
#    'premium': False,
#    'name': 'Программист С++ Senior',
#    'department': None,
#    'has_test': False,
#    'response_letter_required': False,
#    'area': {'id': '1', 'name': 'Москва', 'url': 'https://api.hh.ru/areas/1'},
#    'salary': {'from': 400000, 'to': None, 'currency': 'RUR', 'gross': False},
#    'type': {'id': 'open', 'name': 'Открытая'},
#    'address': {'city': 'Москва',
#     'street': 'проспект Вернадского',
#     'building': '29',
#     'description': None,
#     'lat': 55.681712,
#     'lng': 37.516449,
#     'raw': 'Москва, проспект Вернадского, 29',
#     'metro': None,
#     'metro_stations': [],
#     'id': '6040213'},
#    'response_url': None,
#    'sort_point_distance': None,
#    'published_at': '2022-05-09T10:44:05+0300',
#    'created_at': '2022-05-09T10:44:05+0300',
#    'archived': False,
#    'apply_alternate_url': 'https://hh.ru/applicant/vacancy_response?vacancyId=54081874',
#    'insider_interview': None,
#    'url': 'https://api.hh.ru/vacancies/54081874?host=hh.ru',
#    'alternate_url': 'https://hh.ru/vacancy/54081874',
#    'relations': [],
#    'employer': {'id': '2334358',
#     'name': 'Айти Прайм',
#     'url': 'https://api.hh.ru/employers/2334358',
#     'alternate_url': 'https://hh.ru/employer/2334358',
#     'logo_urls': {'90': 'https://hhcdn.ru/employer-logo/3627707.png',
#      '240': 'https://hhcdn.ru/employer-logo/3627708.png',
#      'original': 'https://hhcdn.ru/employer-logo-original/796705.png'},
#     'vacancies_url': 'https://api.hh.ru/vacancies?employer_id=2334358',
#     'trusted': True},
#    'snippet': {'requirement': 'Опыт разработки С от 3-х лет. Опыт разработки многопоточных сетевых приложений на С под Linux. Знание С11, STL...',
#     'responsibility': 'Разрабатывать приложения, работающие с биржевой инфраструктурой. Проектировать компоненты low-latency торговой платформы.'},
#    'contacts': None,
#    'schedule': {'id': 'flexible', 'name': 'Гибкий график'},
#    'working_days': [],
#    'working_time_intervals': [],
#    'working_time_modes': [],
#    'accept_temporary': False},
#   {'id': '55254774',
#    'premium': False,
#    'name': 'Ведущий инженер-программист',
#    'department': None,
#    'has_test': False,
#    'response_letter_required': False,
#    'area': {'id': '1', 'name': 'Москва', 'url': 'https://api.hh.ru/areas/1'},
#    'salary': None,
#    'type': {'id': 'open', 'name': 'Открытая'},
#    'address': {'city': 'Москва',
#     'street': '2-й Кожевнический переулок',
#     'building': '12с10',
#     'description': None,
#     'lat': 55.72563,
#     'lng': 37.648528,
#     'raw': 'Москва, 2-й Кожевнический переулок, 12с10',
#     'metro': None,
#     'metro_stations': [],
#     'id': '5673821'},
#    'response_url': None,
#    'sort_point_distance': None,
#    'published_at': '2022-05-09T14:34:24+0300',
#    'created_at': '2022-05-09T14:34:24+0300',
#    'archived': False,
#    'apply_alternate_url': 'https://hh.ru/applicant/vacancy_response?vacancyId=55254774',
#    'insider_interview': None,
#    'url': 'https://api.hh.ru/vacancies/55254774?host=hh.ru',
#    'alternate_url': 'https://hh.ru/vacancy/55254774',
#    'relations': [],
#    'employer': {'id': '1181438',
#     'name': 'Институт инженерной физики, МОУ',
#     'url': 'https://api.hh.ru/employers/1181438',
#     'alternate_url': 'https://hh.ru/employer/1181438',
#     'logo_urls': {'original': 'https://hhcdn.ru/employer-logo-original/61382.png',
#      '240': 'https://hhcdn.ru/employer-logo/837384.png',
#      '90': 'https://hhcdn.ru/employer-logo/837383.png'},
#     'vacancies_url': 'https://api.hh.ru/vacancies?employer_id=1181438',
#     'trusted': True},
#    'snippet': {'requirement': 'Образование высшее (техническое). Умение писать понятный и воспроизводимый код. Опыт работы с данными (на примере минимум 3-х библиотек Рython). ',
#     'responsibility': 'Анализ функциональных требований и выдача предложений по их технической реализации. Разработка Back/Frontend функциональных приложений. Выдача исходных данных для разработки...'},
#    'contacts': None,
#    'schedule': {'id': 'fullDay', 'name': 'Полный день'},
#    'working_days': [],
#    'working_time_intervals': [],
#    'working_time_modes': [],
#    'accept_temporary': False},
#   {'id': '54557388',
#    'premium': False,
#    'name': 'Senior ASP.NET Core Developer (C# Senior разработчик)',
#    'department': None,
#    'has_test': False,
#    'response_letter_required': False,
#    'area': {'id': '1', 'name': 'Москва', 'url': 'https://api.hh.ru/areas/1'},
#    'salary': {'from': 300000, 'to': 350000, 'currency': 'RUR', 'gross': False},
#    'type': {'id': 'open', 'name': 'Открытая'},
#    'address': None,
#    'response_url': None,
#    'sort_point_distance': None,
#    'published_at': '2022-05-07T13:50:14+0300',
#    'created_at': '2022-05-07T13:50:14+0300',
#    'archived': False,
#    'apply_alternate_url': 'https://hh.ru/applicant/vacancy_response?vacancyId=54557388',
#    'insider_interview': None,
#    'url': 'https://api.hh.ru/vacancies/54557388?host=hh.ru',
#    'alternate_url': 'https://hh.ru/vacancy/54557388',
#    'relations': [],
#    'employer': {'id': '5076748',
#     'name': 'Mobigility Inc.',
#     'url': 'https://api.hh.ru/employers/5076748',
#     'alternate_url': 'https://hh.ru/employer/5076748',
#     'logo_urls': {'original': 'https://hhcdn.ru/employer-logo-original/799654.png',
#      '90': 'https://hhcdn.ru/employer-logo/3639503.png',
#      '240': 'https://hhcdn.ru/employer-logo/3639504.png'},
#     'vacancies_url': 'https://api.hh.ru/vacancies?employer_id=5076748',
#     'trusted': True},
#    'snippet': {'requirement': 'Глубокое понимание .NET экосистемы. Опыт работы Full-Stack <highlighttext>разработчиком</highlighttext> от 3 лет. Опыт проектирования и разработки высоконагруженных распределённых веб-проектов...',
#     'responsibility': 'Развивать backend экосистему, внедрять новые фичи, рефакторить и улучшать существующие. Договор заключается с юридическим лицом в РФ, расчет производится в...'},
#    'contacts': None,
#    'schedule': {'id': 'remote', 'name': 'Удаленная работа'},
#    'working_days': [],
#    'working_time_intervals': [],
#    'working_time_modes': [],
#    'accept_temporary': True},
#   {'id': '55254287',
#    'premium': False,
#    'name': 'Старший С++ разработчик (Лимасcол, Кипр)',
#    'department': None,
#    'has_test': False,
#    'response_letter_required': False,
#    'area': {'id': '1', 'name': 'Москва', 'url': 'https://api.hh.ru/areas/1'},
#    'salary': {'from': 5500, 'to': 7000, 'currency': 'EUR', 'gross': True},
#    'type': {'id': 'open', 'name': 'Открытая'},
#    'address': {'city': 'Лимассол',
#     'street': None,
#     'building': None,
#     'description': None,
#     'lat': 34.687526,
#     'lng': 33.042165,
#     'raw': 'Лимассол',
#     'metro': None,
#     'metro_stations': [],
#     'id': '1143417'},
#    'response_url': None,
#    'sort_point_distance': None,
#    'published_at': '2022-05-06T14:22:08+0300',
#    'created_at': '2022-05-06T14:22:08+0300',
#    'archived': False,
#    'apply_alternate_url': 'https://hh.ru/applicant/vacancy_response?vacancyId=55254287',
#    'insider_interview': None,
#    'url': 'https://api.hh.ru/vacancies/55254287?host=hh.ru',
#    'alternate_url': 'https://hh.ru/vacancy/55254287',
#    'relations': [],
#    'employer': {'id': '988940',
#     'name': 'MetaQuotes Software Corp.',
#     'url': 'https://api.hh.ru/employers/988940',
#     'alternate_url': 'https://hh.ru/employer/988940',
#     'logo_urls': {'240': 'https://hhcdn.ru/employer-logo/663792.png',
#      '90': 'https://hhcdn.ru/employer-logo/663791.png',
#      'original': 'https://hhcdn.ru/employer-logo-original/99361.gif'},
#     'vacancies_url': 'https://api.hh.ru/vacancies?employer_id=988940',
#     'trusted': True},
#    'snippet': {'requirement': 'Опыт профессиональной коммерческой разработки на С под Windows. Глубокие знания операционных систем, алгоритмов и структур данных, многопоточной обработки и межпроцессных...',
#     'responsibility': 'Развитие собственного языка MQL5 (входит в рейтинг TIOBE) и компилятора, а также средств разработки (отладчик, профилировщик, оптимизатор). '},
#    'contacts': None,
#    'schedule': {'id': 'fullDay', 'name': 'Полный день'},
#    'working_days': [],
#    'working_time_intervals': [],
#    'working_time_modes': [],
#    'accept_temporary': False},
#   {'id': '55216707',
#    'premium': False,
#    'name': 'Ведущий программист 1C',
#    'department': {'id': 'CG-37318-cg', 'name': 'Crocus Group'},
#    'has_test': False,
#    'response_letter_required': False,
#    'area': {'id': '1', 'name': 'Москва', 'url': 'https://api.hh.ru/areas/1'},
#    'salary': {'from': None, 'to': 287356, 'currency': 'RUR', 'gross': True},
#    'type': {'id': 'open', 'name': 'Открытая'},
#    'address': None,
#    'response_url': None,
#    'sort_point_distance': None,
#    'published_at': '2022-05-05T10:51:38+0300',
#    'created_at': '2022-05-05T10:51:38+0300',
#    'archived': False,
#    'apply_alternate_url': 'https://hh.ru/applicant/vacancy_response?vacancyId=55216707',
#    'insider_interview': None,
#    'url': 'https://api.hh.ru/vacancies/55216707?host=hh.ru',
#    'alternate_url': 'https://hh.ru/vacancy/55216707',
#    'relations': [],
#    'employer': {'id': '37318',
#     'name': 'Crocus Group',
#     'url': 'https://api.hh.ru/employers/37318',
#     'alternate_url': 'https://hh.ru/employer/37318',
#     'logo_urls': None,
#     'vacancies_url': 'https://api.hh.ru/vacancies?employer_id=37318',
#     'trusted': True},
#    'snippet': {'requirement': 'Опыт программирования в 1С:Предприятие 8. Опыт работы с типовыми решениями на базе 1С:Предприятие 8. ',
#     'responsibility': 'Разработка нового функционала для управленческих\\типовых баз. Настройка и доработка обмена с другими инф.системами. Поддержка, доработка и кастомизация «1С...'},
#    'contacts': None,
#    'schedule': {'id': 'fullDay', 'name': 'Полный день'},
#    'working_days': [],
#    'working_time_intervals': [],
#    'working_time_modes': [],
#    'accept_temporary': False}],
#  'found': 4740,
#  'pages': 100,
#  'per_page': 20,
#  'page': 0,
#  'clusters': None,
#  'arguments': None,
#  'alternate_url': 'https://hh.ru/search/vacancy?area=1&enable_snippets=true&specialization=1&text=%D0%92%D0%B5%D0%B4%D1%83%D1%89%D0%B8%D0%B9+%D0%BF%D1%80%D0%BE%D0%B3%D1%80%D0%B0%D0%BC%D0%BC%D0%B8%D1%81%D1%82'}

# %%
data = pd.json_normalize(answer, record_path='items')

# %%
data.head(20)
# Out:
#           id  premium                                               name  \
# 0   51794644    False                                Ведущий программист
# 1   54892884    False                                Ведущий программист
# 2   54718245    False                              C# .Net MVC Developer
# 3   55254339    False              Full stack C# Developer (C# JS), Кипр
# 4   55243692    False                 Ведущий программист/Разработчик 1С
# 5   55269828    False                   С/С++ Linux разработчик (remote)
# 6   54981052    False                            Ведущий программист С++
# 7   55001846    False                             Ведущий программист 1С
# 8   55262147    False                             Ведущий программист 1C
# 9   54497894    False                                   Разработчик Rust
# 10  55134106    False                            Ведущий программист PHP
# 11  54926043    False             Ведущий программист 1С / архитектор 1С
# 12  47901543    False        Middle BackEnd Developer .Net C# (удаленно)
# 13  48775503    False                         Разработчик интерпретатора
# 14  54814745    False                             Ведущий программист 1С
# 15  54081874    False                             Программист С++ Senior
# 16  55254774    False                        Ведущий инженер-программист
# 17  54557388    False  Senior ASP.NET Core Developer (C# Senior разра...
# 18  55254287    False           Старший С++ разработчик (Лимасcол, Кипр)
# 19  55216707    False                             Ведущий программист 1C
#
#     department  has_test  response_letter_required  salary response_url  \
# 0          NaN     False                     False     NaN         None
# 1          NaN     False                     False     NaN         None
# 2          NaN     False                     False     NaN         None
# 3          NaN     False                     False     NaN         None
# 4          NaN     False                     False     NaN         None
# 5          NaN     False                     False     NaN         None
# 6          NaN     False                     False     NaN         None
# 7          NaN     False                     False     NaN         None
# 8          NaN     False                     False     NaN         None
# 9          NaN     False                     False     NaN         None
# 10         NaN     False                     False     NaN         None
# 11         NaN     False                     False     NaN         None
# 12         NaN     False                     False     NaN         None
# 13         NaN     False                     False     NaN         None
# 14         NaN     False                     False     NaN         None
# 15         NaN     False                     False     NaN         None
# 16         NaN     False                     False     NaN         None
# 17         NaN     False                     False     NaN         None
# 18         NaN     False                     False     NaN         None
# 19         NaN     False                     False     NaN         None
#
#    sort_point_distance              published_at  ...     schedule.name  \
# 0                 None  2022-05-08T15:45:08+0300  ...       Полный день
# 1                 None  2022-05-09T14:52:19+0300  ...       Полный день
# 2                 None  2022-05-08T10:54:21+0300  ...  Удаленная работа
# 3                 None  2022-05-06T14:23:27+0300  ...       Полный день
# 4                 None  2022-05-06T10:33:46+0300  ...       Полный день
# 5                 None  2022-05-09T16:51:27+0300  ...  Удаленная работа
# 6                 None  2022-05-09T14:41:41+0300  ...     Гибкий график
# 7                 None  2022-05-07T12:40:33+0300  ...  Удаленная работа
# 8                 None  2022-05-06T19:17:43+0300  ...     Гибкий график
# 9                 None  2022-05-09T14:12:28+0300  ...  Удаленная работа
# 10                None  2022-05-07T18:26:26+0300  ...       Полный день
# 11                None  2022-05-07T15:23:07+0300  ...  Удаленная работа
# 12                None  2022-05-08T14:45:04+0300  ...  Удаленная работа
# 13                None  2022-05-07T23:44:58+0300  ...  Удаленная работа
# 14                None  2022-05-08T13:23:28+0300  ...       Полный день
# 15                None  2022-05-09T10:44:05+0300  ...     Гибкий график
# 16                None  2022-05-09T14:34:24+0300  ...       Полный день
# 17                None  2022-05-07T13:50:14+0300  ...  Удаленная работа
# 18                None  2022-05-06T14:22:08+0300  ...       Полный день
# 19                None  2022-05-05T10:51:38+0300  ...       Полный день
#
#     address salary.from salary.to salary.currency salary.gross address.metro  \
# 0       NaN         NaN       NaN             NaN          NaN           NaN
# 1       NaN         NaN       NaN             NaN          NaN           NaN
# 2       NaN      6000.0    7500.0             USD         True           NaN
# 3       NaN      7000.0       NaN             EUR         True           NaN
# 4       NaN    250000.0       NaN             RUR         True           NaN
# 5       NaN         NaN    6000.0             USD         True           NaN
# 6       NaN    150000.0  350000.0             RUR        False           NaN
# 7       NaN    150000.0  300000.0             RUR        False           NaN
# 8       NaN         NaN  250000.0             RUR         True           NaN
# 9       NaN         NaN  300000.0             RUR        False           NaN
# 10      NaN         NaN  300000.0             RUR        False           NaN
# 11      NaN    108000.0  395000.0             RUR         True           NaN
# 12      NaN    200000.0  240000.0             RUR        False           NaN
# 13      NaN    300000.0       NaN             RUR        False           NaN
# 14      NaN    200000.0  250000.0             RUR        False           NaN
# 15      NaN    400000.0       NaN             RUR        False           NaN
# 16      NaN         NaN       NaN             NaN          NaN           NaN
# 17      NaN    300000.0  350000.0             RUR        False           NaN
# 18      NaN      5500.0    7000.0             EUR         True           NaN
# 19      NaN         NaN  287356.0             RUR         True           NaN
#
#    department.id department.name employer.logo_urls
# 0            NaN             NaN                NaN
# 1            NaN             NaN                NaN
# 2            NaN             NaN                NaN
# 3            NaN             NaN                NaN
# 4            NaN             NaN                NaN
# 5            NaN             NaN                NaN
# 6            NaN             NaN                NaN
# 7            NaN             NaN                NaN
# 8            NaN             NaN                NaN
# 9            NaN             NaN                NaN
# 10           NaN             NaN                NaN
# 11           NaN             NaN                NaN
# 12           NaN             NaN                NaN
# 13           NaN             NaN                NaN
# 14           NaN             NaN                NaN
# 15           NaN             NaN                NaN
# 16           NaN             NaN                NaN
# 17           NaN             NaN                NaN
# 18           NaN             NaN                NaN
# 19   CG-37318-cg    Crocus Group                NaN
#
# [20 rows x 64 columns]
