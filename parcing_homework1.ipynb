# %%
import requests
import json

# %%
url = 'https://api.github.com/users/alexanechka/repos'
params = {
    
}
req = requests.get(url, params)
if req.status_code == 200:
    answer = req.json()
else:
    answer = req.status_code
    
answer
# Out:
# [{'id': 475500164,
#   'node_id': 'R_kgDOHFeOhA',
#   'name': 'app_desing',
#   'full_name': 'alexanechka/app_desing',
#   'private': False,
#   'owner': {'login': 'alexanechka',
#    'id': 83138709,
#    'node_id': 'MDQ6VXNlcjgzMTM4NzA5',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/83138709?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/alexanechka',
#    'html_url': 'https://github.com/alexanechka',
#    'followers_url': 'https://api.github.com/users/alexanechka/followers',
#    'following_url': 'https://api.github.com/users/alexanechka/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/alexanechka/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/alexanechka/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/alexanechka/subscriptions',
#    'organizations_url': 'https://api.github.com/users/alexanechka/orgs',
# ...

# %%
json.dump(answer, fp = open("result.txt", "w+"))

# %%
req.content
# Out:
# b'[{"id":475500164,"node_id":"R_kgDOHFeOhA","name":"app_desing","full_name":"alexanechka/app_desing","private":false,"owner":{"login":"alexanechka","id":83138709,"node_id":"MDQ6VXNlcjgzMTM4NzA5","avatar_url":"https://avatars.githubusercontent.com/u/83138709?v=4","gravatar_id":"","url":"https://api.github.com/users/alexanechka","html_url":"https://github.com/alexanechka","followers_url":"https://api.github.com/users/alexanechka/followers","following_url":"https://api.github.com/users/alexanechka/following{/other_user}","gists_url":"https://api.github.com/users/alexanechka/gists{/gist_id}","starred_url":"https://api.github.com/users/alexanechka/starred{/owner}{/repo}","subscriptions_url":"https://api.github.com/users/alexanechka/subscriptions","organizations_url":"https://api.github.com/users/alexanechka/orgs","repos_url":"https://api.github.com/users/alexanechka/repos","events_url":"https://api.github.com/users/alexanechka/events{/privacy}","received_events_url":"https://api.github.co
# ...

# %%
url = 'https://api.github.com/authorizations'
params = {
    
}
req = requests.get(url, params)
if req.status_code == 200:
    answer = req.json()
else:
    answer = req.status_code
    
answer
# Out:
# 404

# %%
import os

# %%
username = 'alexanechka'

token = '***'

# %%
r = requests.get('https://api.github.com/user', auth=(username, token))
r.text
# Out:
# '{"login":"alexanechka","id":83138709,"node_id":"MDQ6VXNlcjgzMTM4NzA5","avatar_url":"https://avatars.githubusercontent.com/u/83138709?v=4","gravatar_id":"","url":"https://api.github.com/users/alexanechka","html_url":"https://github.com/alexanechka","followers_url":"https://api.github.com/users/alexanechka/followers","following_url":"https://api.github.com/users/alexanechka/following{/other_user}","gists_url":"https://api.github.com/users/alexanechka/gists{/gist_id}","starred_url":"https://api.github.com/users/alexanechka/starred{/owner}{/repo}","subscriptions_url":"https://api.github.com/users/alexanechka/subscriptions","organizations_url":"https://api.github.com/users/alexanechka/orgs","repos_url":"https://api.github.com/users/alexanechka/repos","events_url":"https://api.github.com/users/alexanechka/events{/privacy}","received_events_url":"https://api.github.com/users/alexanechka/received_events","type":"User","site_admin":false,"name":"Alexandra","company":null,"blog":"","location"
# ...
